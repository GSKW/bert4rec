# %% [markdown]
# # 10 Final Tables And Plots
#
# Collects final metrics tables and plots.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks": PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %%
from src.final_report import build_final_report, load_final_report_config
config = load_final_report_config(PROJECT_ROOT / "configs" / "final_report.yaml")
config

# %%
manifest = build_final_report(config, PROJECT_ROOT)
manifest

# %%
import pandas as pd
pd.read_excel(PROJECT_ROOT / config.output_xlsx, sheet_name="best_downstream")
