# %% [markdown]
# # 00 W&B Smoke Test
#
# Проверяет базовый W&B workflow: создание run, логирование toy-метрик, сохранение checkpoint и resume по `run_id` из `artifacts/manifests/smoke_state.json`.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

PROJECT_ROOT

# %% [markdown]
# Первый запуск создаст `run_id`, checkpoint и state-файл. Повторный запуск с теми же параметрами продолжит тот же run и увеличит `global_step`.

# %%
# %run {PROJECT_ROOT / 'scripts' / 'wandb_smoke_test.py'} --mode offline --steps 30 --resume

# %% [markdown]
# Для online-режима сначала выполните `wandb login`, затем запустите:
#
# ```bash
# .venv/bin/python scripts/wandb_smoke_test.py --mode online --steps 30 --resume
# ```
